# %% [markdown]
# <a href="https://colab.research.google.com/github/rubisabel00/estructura-de-datos-con-python/blob/main/Estructuras_de_Datos_con_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estructuras de datos con python
# ![image.png](data:image/png;base64,...)
#
# Las estructuras de datos son formas de organizar y almacenar información, son fundamentales en la programación y se utilizan para diseñar soluciones a problemas específicos.
#
# **Características** :
#
# * Permiten realizar operaciones con los datos de manera eficiente
# * Facilitan el acceso y el trabajo con los datos
# * Son útiles para crear algoritmos y optimizar recursos
# * Se pueden utilizar en la red para indexar contenidos

# %% [markdown]
# # Listas
# Son estructuras de datos que permiten almacenar y organizar valores de cualquier tipo. Son mutables, es decir, se pueden modificar, eliminar o agregar elementos.
#
# Pueden ser homogéneas o heterogéneas - puede contener distintos tipos de datos.
#
# # *Características de las listas en python*
# * Son ordenadas, cada elemento tiene un índice y mantiene el orden definido.
# * Permiten elementos duplicados.
# * Pueden anidar, es decir, contener una lista dentro de otra.
# * Son dinámicas, lo que significa que se puede modificar su tamaño.

# %%
#Listas
lista = [1, 2, 3] #lista homogenea
print(lista)

lista2 = [20, True, "soy un texto dentro de la lista"] #lista heterogenea   la posición se lee como  de 0 a n-1
print(lista2)

print(lista2[1]) #imprime ek contenido de la lista en la posición 1 = True
lista2[0]= 50
print(lista2)
# Out:
# [1, 2, 3]
# [20, True, 'soy un texto dentro de la lista']
# True
# [50, True, 'soy un texto dentro de la lista']

# %% [markdown]
# ## Métodos para las listas en python

# %%
#metodo append
lista_nueva = [1, 2, 3, 4, 5]
lista_nueva.append(3) #agrega el valor 3 en la ultima posición de la lista
print(lista_nueva)

#metodo count
print(lista_nueva.count(3)) #devuelve la cantidad de veces que se repite  un valor de la lista

#metodo index
print(lista_nueva.index(3)) #muestra la primera posición del elemento dentro de la lista

#metodo remove
#elimina la primera aparición de un elemento dentro de la lista
lista_nueva.remove(3)
print(lista_nueva)
# Out:
# [1, 2, 3, 4, 5, 3]
# 2
# 2
# [1, 2, 4, 5, 3]

# %% [markdown]
# ---
# # Tuplas
# una tupla es una colección de elementos ordenados que no se pueden modificar. Se pueden usar para almacenar datos de diferentes tipos, como números, cadenas, o valores booleanos.
#
# *Características de las tuplas*
#
# * Se crean escribiendo los elementos entre paréntesis y separados por comas.
# * Son inmutables, es decir, no se pueden cambiar sus valores.
# * Se pueden concatenar.
# * Se pueden referir a los elementos de las tuplas de forma individual usando corchetes.
# * Se pueden usar para comprobar condiciones y para plantear estructuras de código condicional.

# %%
#tuplas
tupla = (1, 2, 3) #tupla homogenea
print(tupla)
print((1, ))

tupla2 = (5, False, "soy un texto de una tupla", True)
print(tupla2)

#acceder al contenido de una tupla
print(tupla2[0])
# Out:
# (1, 2, 3)
# (1,)
# (5, False, 'soy un texto de una tupla', True)
# 5

# %% [markdown]
# # Métodos para las tuplas en python

# %%
#count
#sirve para contar cuantos elementos se repiten dentro de la tupla
print(tupla2.count(False))

#index
#devuelve la primera posición del elemento buscado dentro de la tupla
print(tupla2.index(True))
# Out:
# 1
# 3

# %% [markdown]
# ---
# ---
# # Conjuntos
#
# ![image.png](data:image/png;base64,...)
#
# Un conjunto es una colección de elementos no ordenados, heterogéneos y únicos, es decir los elementos no se pueden repetir. Los conjuntos admiten agregar, eliminar y actualizar elementos, También admiten operaciones matemáticas comunes como la unión, la intersección y la diferencia.
#
# *Características de los conjuntos*
# * Se usa el constructor set() para declararlos
# * Los elementos de un set son único, lo que significa que no puede haber elementos duplicados.
# * Los set son desordenados, lo que significa que no mantienen el orden de cuando son declarados.

# %%
set() #construir conjuntos
# no muestra elementos repetidos de la lista del conjunto
conjunto = set([1, 2, 3, 4, 4, 5])
print(conjunto)

#podemos declarar tambien dentro del conjunto una lista, una tupla o un string
print(set([1, 2, 3]))
print(set((2, 3, 4, 4)))
print(set("Hola")) # un string lo obtiene como un conjunto de char, python lo interpreta como una lista de caracteres desordenado
# Out:
# {1, 2, 3, 4, 5}
# {1, 2, 3}
# {2, 3, 4}
# {'a', 'l', 'H', 'o'}

# %% [markdown]
# # Métodos para trabajar conjuntos en python

# %%
#metodo add
# podemos añadir elementos al conjunto

conjunto.add(0)
print(conjunto)

#metodo remove
#elimina elementos del conjunto

conjunto.remove(1)
print(conjunto)
# Out:
# {0, 1, 2, 3, 4, 5}
# {0, 2, 3, 4, 5}

# %% [markdown]
# # Operaciones con conjuntos
#
# ![operadores conjuntos.png](data:image/png;base64,...)

# %%
#intersección
conjunto_A = set([2, 4, 5, 7, 10, 12])
conjunto_B = set([1, 3, 7])

print(conjunto, conjunto_A, conjunto_B)
print(conjunto.intersection(conjunto_A)) #aplicamos la intersección entre conjuntos y este imprime los valores que son comunes en ambos

print(conjunto & conjunto_A) #aplicando intersección con el simbolo &

#unión
#une los elementos de dos conjuntos
print(conjunto_A.union(conjunto))

print(conjunto_A | conjunto) #aplicando la unión con el simbolo |
# Out:
# {0, 2, 3, 4, 5} {2, 4, 5, 7, 10, 12} {1, 3, 7}
# {2, 4, 5}
# {2, 4, 5}
# {0, 2, 3, 4, 5, 7, 10, 12}
# {0, 2, 3, 4, 5, 7, 10, 12}

# %% [markdown]
# ---
# #Diccionarios
# Un diccionario nos permite relacionar pares de elementos utilizando clave:valor.
# La clave a la que llamaremos key nos sirve para identificar y buscar el elemento con el que tiene relación, y ese elemento es el elemento value.
# {key : value}
#
# *Características de los diccionarios*
#
#
# * no son ordenados
# * son heterogeneos con clave inmutable {(1, 2): ["uno","dos"], 1: "uno"}
# * mutables

# %%
from os import pidfd_open
#diccionario

{} #diccionario vacio
diccionario = {1: "uno", 2: "dos"} #creamos el diccionario con clave y valor separados por comas
print(diccionario)

#podemos ver el valor de una key usando corchetes
print(diccionario[2])

#podemos cambiar el valor de una key usando el simbolo =
diccionario[3] = "tres"
print(diccionario)

#podemos crear diccionarios utilizando la propiedad dict

dict_lista_tupla = dict([(1, "uno"), (2, "dos"), (3, "tres")])
print(dict_lista_tupla)

#cuando las key son tipo string esccribimos los datos con igual y sin comillas
dict_lista_string = dict(uno = 1, dos = 2, tres = 3)
print(dict_lista_string)

#En el diccionario se pueden varios tipos de datos
dict_datos = {1: "integer", 2.2: "float", "tres": "string", (1, 2): "tupla"}
print(dict_datos)

#las key siempre deben ser unicas, en caso de repetir una key solo tomará el ultimo valor asignado
dict_repeticion = {1: "uno", 1: "texto"}
print(dict_repeticion)
# Out:
# {1: 'uno', 2: 'dos'}
# dos
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {'uno': 1, 'dos': 2, 'tres': 3}
# {1: 'integer', 2.2: 'float', 'tres': 'string', (1, 2): 'tupla'}
# {1: 'texto'}

# %% [markdown]
# ## Métodos en los diccionarios

# %%
#keys  = devuelve una lista con las claves
print(diccionario.keys())

#values  = devuelve una lista con los valores
print(diccionario.values())

#pop  = para eliminar una clave y su valor
diccionario.pop(2)
print(diccionario)

#items  = devuelve una lista de tuplas con los pares de datos key-value
print(diccionario.items())
# Out:
# dict_keys([1, 2, 3])
# dict_values(['uno', 'dos', 'tres'])
# {1: 'uno', 3: 'tres'}
